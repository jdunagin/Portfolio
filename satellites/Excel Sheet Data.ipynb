# %% [markdown]
# # Summary
# Cleaning a dataset containing satellites and their parameters. Ultimately, going to combine with other sources to get a larger set of data.

# %%
# imports
import pandas as pd

# %%
# read excel
sat_df = pd.read_excel('data/UCS-Satellite-Database-1-1-2022.xls')

# %%
# look at it
sat_df.head()
# Out:
#                   Name of Satellite, Alternate Names
# 0  1HOPSAT-TD (1st-generation High Optical Perfor...  \
# 1                                           Aalto-1
# 2                                           AAUSat-4
# 3                           ABS-2 (Koreasat-8, ST-3)
# 4                                             ABS-2A
#
#   Current Official Name of Satellite Country/Org of UN Registry
# 0                         1HOPSAT-TD                         NR  \
# 1                            Aalto-1                    Finland
# 2                           AAUSat-4                    Denmark
# 3                              ABS-2                         NR
# 4                             ABS-2A                         NR
#
#   Country of Operator/Owner                 Operator/Owner       Users
# 0                       USA                   Hera Systems  Commercial  \
# 1                   Finland               Aalto University       Civil
# 2                   Denmark          University of Aalborg       Civil
# 3             Multinational  Asia Broadcast Satellite Ltd.  Commercial
# 4             Multinational  Asia Broadcast Satellite Ltd.  Commercial
#
#                   Purpose                       Detailed Purpose
# 0       Earth Observation                       Infrared Imaging  \
# 1  Technology Development                                    NaN
# 2       Earth Observation  Automatic Identification System (AIS)
# 3          Communications                                    NaN
# 4          Communications                                    NaN
#
#   Class of Orbit       Type of Orbit  ... Unnamed: 57  Unnamed: 58
# 0            LEO  Non-Polar Inclined  ...         NaN          NaN  \
# 1            LEO     Sun-Synchronous  ...         NaN          NaN
# 2            LEO     Sun-Synchronous  ...         NaN          NaN
# 3            GEO                 NaN  ...         NaN          NaN
# 4            GEO                 NaN  ...         NaN          NaN
#
#    Unnamed: 59  Unnamed: 60  Unnamed: 61  Unnamed: 62  Unnamed: 63
# 0          NaN          NaN          NaN          NaN          NaN  \
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 64 Unnamed: 65 Unnamed: 66
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# # Step 1 - Unwanted Columns
#
# Some columns I don't want for the simple reason that they have information I don't care about. I mostly care about the parameters, characteristics, and names of these satellites. Other information might not be needed. Let's take a look:

# %%
# look at row names, do we need all of these?
for column in sat_df:
    print(column)
# Out:
# Name of Satellite, Alternate Names
# Current Official Name of Satellite
# Country/Org of UN Registry
# Country of Operator/Owner
# Operator/Owner
# Users
# Purpose
# Detailed Purpose
# Class of Orbit
# Type of Orbit
# Longitude of GEO (degrees)
# Perigee (km)
# Apogee (km)
# Eccentricity
# Inclination (degrees)
# Period (minutes)
# Launch Mass (kg.)
# Dry Mass (kg.)
# Power (watts)
# Date of Launch
# Expected Lifetime (yrs.)
# Contractor
# Country of Contractor
# Launch Site
# Launch Vehicle
# COSPAR Number
# NORAD Number
# Comments
# Unnamed: 28
# Source Used for Orbital Data
# Source
# Source.1
# Source.2
# Source.3
# Source.4
# Source.5
# Source.6
# Unnamed: 37
# Unnamed: 38
# Unnamed: 39
# Unnamed: 40
# Unnamed: 41
# Unnamed: 42
# Unnamed: 43
# Unnamed: 44
# Unnamed: 45
# Unnamed: 46
# Unnamed: 47
# Unnamed: 48
# Unnamed: 49
# Unnamed: 50
# Unnamed: 51
# Unnamed: 52
# Unnamed: 53
# Unnamed: 54
# Unnamed: 55
# Unnamed: 56
# Unnamed: 57
# Unnamed: 58
# Unnamed: 59
# Unnamed: 60
# Unnamed: 61
# Unnamed: 62
# Unnamed: 63
# Unnamed: 64
# Unnamed: 65
# Unnamed: 66

# %% [markdown]
# I don't care about the source or any of the unnamed columns. Those will be removed.

# %%
# pick the removes
removes = ['Source Used for Orbital Data', 'Source', 'Source.1', 'Source.2', 'Source.3',
          'Source.4', 'Source.5', 'Source.6', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
           'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
           'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50',
           'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
           'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62',
           'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 28']
sat_df.drop(columns=removes, inplace=True)

# %% [markdown]
# That's a bit better. Let's look at null values next.
#
# # Step 2 -  Incomplete Columns
#
# Some columns may be relevant if they were full, but be so incomplete as to render them useless here. I will look at columns with too much incomplete data. I will then choose a threshold for removal based on how much is missing. Hopefully there will be an easy line to draw here.

# %%
# how many null values in each column?
for column in sat_df:
    print(column, len(sat_df[column][sat_df[column].isnull()]))
# Out:
# Name of Satellite, Alternate Names 2
# Current Official Name of Satellite 2
# Country/Org of UN Registry 3
# Country of Operator/Owner 2
# Operator/Owner 2
# Users 2
# Purpose 2
# Detailed Purpose 3810
# Class of Orbit 2
# Type of Orbit 632
# Longitude of GEO (degrees) 2
# Perigee (km) 2
# Apogee (km) 2
# Eccentricity 2
# Inclination (degrees) 2
# Period (minutes) 17
# Launch Mass (kg.) 242
# Dry Mass (kg.) 4401
# Power (watts) 4262
# Date of Launch 2
# Expected Lifetime (yrs.) 1759
# Contractor 4
# Country of Contractor 4
# Launch Site 3
# Launch Vehicle 2
# COSPAR Number 2
# NORAD Number 2
# Comments 3336

# %% [markdown]
# It looks like some columns have a LOT of null values, and some have very few. This makes it easy to pick a cut off. 100 will easily take care of the big ones while not touching the ones with few null values.

# %%
# remove columns if too many null values:
for column in sat_df:
    if len(sat_df[column][sat_df[column].isnull()]) > 100:
        sat_df.drop(columns=column, inplace=True)

# %% [markdown]
# # Step 3 - Rows
#
# We now need to deal with rows with null values. It's possible we might be able to come up with estimates for particular parameters. However, we can already see that there are so few null values compared to the number of satellites as a whole that if we were to straight up remove them, we would still have a similar sized data set. I'm just going to remove the rows with a null value.

# %%
# drop any rows with null values - we won't miss them
sat_df.dropna(inplace=True)
len(sat_df)
# Out:
# 4832

# %% [markdown]
# The length is not much different. And now we have no null values!

# %% [markdown]
# # Step 4 - New Parameter
#
# I would like to add a new column for the orbital parameter semi-major axis. This refers to the size of the orbit. It is already implied through other parameters listed here, but I wanted to list it explicitly. It will involve very simple arithmetic.

# %%
# semi-major axis
sat_df['Semi-Major Axis (km)'] = (sat_df['Perigee (km)'] + sat_df['Apogee (km)']) / 2

# %% [markdown]
# # Step 5 - Sort by NORAD Number
#
# The NORAD Number is an identifier used for the sattelites. There's no great reason to sort it by that, but we can do it anyway. It sort of is like sorting by age, because they are cataloged in chronological order.

# %%
sat_df.sort_values('NORAD Number', inplace=True)
sat_df.head()
# Out:
#                      Name of Satellite, Alternate Names
# 77                                 Amsat-Oscar 7 (AO-7)  \
# 4492  TDRS-3 (Tracking and Data Relay Satellite, TDR...
# 735                                FLTSATCOM-8 (USA 46)
# 1018      Hubble Space Telescope (HST, Space Telescope)
# 2434                                         Skynet 4C
#
#      Current Official Name of Satellite Country/Org of UN Registry
# 77                        Amsat-Oscar 7                        USA  \
# 4492                             TDRS-3                        USA
# 735                              USA 46                        USA
# 1018             Hubble Space Telescope                        USA
# 2434                          Skynet 4C             United Kingdom
#
#      Country of Operator/Owner
# 77                         USA  \
# 4492                       USA
# 735                        USA
# 1018                   ESA/USA
# 2434            United Kingdom
#
#                                          Operator/Owner       Users
# 77                                             AMSAT-NA       Civil  \
# 4492  National Aeronautics and Space Administration ...  Government
# 735                                             US Navy    Military
# 1018                   European Space Agency (ESA)/NASA  Government
# 2434  Intelsat/Paradigm Secure Communications (wholl...    Military
#
#              Purpose Class of Orbit Longitude of GEO (degrees)  Perigee (km)
# 77    Communications            LEO                          0        1440.0  \
# 4492  Communications            GEO                        -49       35693.0
# 735   Communications            GEO                     -14.74       35745.0
# 1018   Space Science            LEO                          0         555.0
# 2434  Communications            GEO                       -1.3       35785.0
#
#       ...  Inclination (degrees)  Period (minutes)  Date of Launch
# 77    ...                 101.40            114.90      1974-11-15  \
# 4492  ...                  11.53           1436.06      1988-09-29
# 735   ...                   8.97           1436.13      1989-09-25
# 1018  ...                  28.50             95.80      1990-04-25
# 2434  ...                  13.60           1436.07      1990-08-30
#
#                                 Contractor Country of Contractor
# 77                                Amsat-NA                   USA  \
# 4492   TRW Defense and Space Systems Group                   USA
# 735   TRW, Defense and Space Systems Group                   USA
# 1018            European Space Agency/NASA         International
# 2434                               Astrium     France/UK/Germany
#
#               Launch Site          Launch Vehicle COSPAR Number NORAD Number
# 77         Vandenberg AFB              Delta 2310     1974-089B       7530.0  \
# 4492       Cape Canaveral  Space Shuttle (STS 26)     1988-091B      19548.0
# 735        Cape Canaveral           Atlas Centaur     1989-077A      20253.0
# 1018       Cape Canaveral  Space Shuttle (STS 31)     1990-037B      20580.0
# 2434  Guiana Space Center             Ariane 44LP     1990-079A      20776.0
#
#      Semi-Major Axis (km)
# 77                 1449.5
# 4492              35785.5
# 735               35787.0
# 1018                557.0
# 2434              35786.0
#
# [5 rows x 22 columns]

# %% [markdown]
# Here we have it. A data set ready for use.
#
# Export it as a csv

# %%
from pathlib import Path  
filepath = Path('data/df_1.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
sat_df.to_csv(filepath)
