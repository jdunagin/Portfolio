# %% [markdown]
# # API
# Here, I'll gather data from an API
#
# # Step 1
#
# Import the data, load into a data frame

# %%
# imports
import requests
import pandas as pd

# %%
# requests and read JSON
r = requests.get('https://api.nasa.gov/neo/rest/v1/feed?detailed=true&api_key=DEMO_KEY')
json = r.json()

# %%
# here I loop through the JSON, and extract column names and orbital data to my data frame
NEO = json['near_earth_objects']
first_time = True
for date in NEO: # loop through each day
    sats = NEO[date]
    for sat in sats: # loop through each object
        row = []
        columns = ['name']
        sat_name = sat['name']
        row.append(sat_name)
        orbital_data = sat['orbital_data']
        if first_time: # create the data frame
            for column in orbital_data:
                columns.append(column)
            df = pd.DataFrame(columns=columns[:-2])
            first_time = False
        for column in orbital_data: # create row of data
            row.append(orbital_data[column])
        row = row[:-2]
        df.loc[len(df.index)] = row

# %%
df.head()
# Out:
#                name orbit_id orbit_determination_date first_observation_date
# 0  503871 (2000 SL)       81      2023-03-29 06:36:52             2000-05-04  \
# 1       (2011 EH17)        9      2021-04-15 04:52:51             2011-03-06
# 2      (2011 SH189)       16      2021-04-15 05:24:33             2011-09-11
# 3       (2015 VL64)        6      2021-04-15 15:13:25             2015-11-07
# 4        (2018 SB3)        9      2021-04-15 20:42:07             2018-09-30
#
#   last_observation_date  data_arc_in_days  observations_used
# 0            2023-03-28              8363                320  \
# 1            2021-03-07              3654                 63
# 2            2011-12-02                82                 63
# 3            2015-11-13                 6                 29
# 4            2018-11-02                33                 45
#
#   orbit_uncertainty minimum_orbit_intersection jupiter_tisserand_invariant
# 0                 0                      .1246                       4.162  \
# 1                 3                  .00730455                       7.682
# 2                 4                    .106832                       5.212
# 3                 5                   .0023298                       6.524
# 4                 6                  .00938858                       5.471
#
#    ...    semi_major_axis        inclination ascending_node_longitude
# 0  ...  1.540283568601054  38.35226293577747          207.73368465917  \
# 1  ...   .730849011197336  3.000433805917445        333.1049025630576
# 2  ...  1.223574775504696  5.867995692891024        182.7226027500625
# 3  ...  .9090949676991688  .7069711460919803        51.69155038506252
# 4  ...  1.143541234479607  2.571300070806959             339.57263008
#
#       orbital_period perihelion_distance perihelion_argument
# 0  698.2315207878494   .9324002107085844    70.1980304057716  \
# 1   228.212759525363   .2485366217656095   35.95064504113311
# 2  494.3609973563272   1.094679597955246   217.4615976459775
# 3  316.6010183703575   .6467751993097297   225.1549173308097
# 4  446.6590838233711    .930823879823715    313.744343053062
#
#    aphelion_distance       perihelion_time       mean_anomaly
# 0  2.148166926493524  2460116.161027884589  300.3665277221089  \
# 1  1.213161400629063  2459900.031706017621  158.4862560221435
# 2  1.352469953054146  2459822.533151895040  129.5977345712941
# 3  1.171414736088608  2460096.876437495298  250.4124892683682
# 4  1.356258589135499  2460113.190735501678  269.1730891638002
#
#          mean_motion
# 0  .5155882959763749
# 1  1.577475338139411
# 2   .728212787669651
# 3  1.137077833334303
# 4  .8059838320502175
#
# [5 rows x 22 columns]

# %% [markdown]
# # Step 2
#
# I will turn the column "name" into the row index

# %%
# first strip out the parentheses
df['name'] = df['name'].apply(lambda name: name.replace('(', ''))
df['name'] = df['name'].apply(lambda name: name.replace(')', ''))

# set index
df.set_index('name', inplace=True)

# %% [markdown]
# # Step 3
#
# The numerical values have too many decimal places...I'm going to round them

# %%
# function to round to 2 decimals
def round_2_places(number):
    number = float(number)
    return round(number, 2)

# %%
# round to 2 decimals
for column in df:
    try :
        df[column] = df[column].apply(round_2_places)
    except ValueError:
        pass

# %% [markdown]
# # Step 4 -  Rename columns
#
# Add units to the columns (where known)

# %%
rename_mapper = {'semi_major_axis': 'semi_major_axis (AU)', 'inclination': 'inclination (deg)',
                'ascending_node_longitude': 'ascending_node_longitude (deg)', 'orbital_period':
                'orbital_period (days)', 'perihelion_distance': 'perihelion_distance (AU)',
                'aphelion_distance': 'aphelion_distance (AU)', 'mean_anomaly': 'mean_anomaly (deg)',
                'mean_motion': 'mean_motion (revs/year)'}

df.rename(columns=rename_mapper, inplace=True)

# %% [markdown]
# This is subject to change (maybe later).

# %% [markdown]
# # Step 5 - Drop some columns
#
# Going to drop some columns that I think are redundant, or don't really know the meaning of.

# %%
drops = ['orbit_id', 'jupiter_tisserand_invariant']
df.drop(columns=drops, inplace=True)

# %%
df.head()
# Out:
#                orbit_determination_date first_observation_date
# name
# 503871 2000 SL      2023-03-29 06:36:52             2000-05-04  \
# 2011 EH17           2021-04-15 04:52:51             2011-03-06
# 2011 SH189          2021-04-15 05:24:33             2011-09-11
# 2015 VL64           2021-04-15 15:13:25             2015-11-07
# 2018 SB3            2021-04-15 20:42:07             2018-09-30
#
#                last_observation_date  data_arc_in_days  observations_used
# name
# 503871 2000 SL            2023-03-28            8363.0              320.0  \
# 2011 EH17                 2021-03-07            3654.0               63.0
# 2011 SH189                2011-12-02              82.0               63.0
# 2015 VL64                 2015-11-13               6.0               29.0
# 2018 SB3                  2018-11-02              33.0               45.0
#
#                 orbit_uncertainty  minimum_orbit_intersection
# name
# 503871 2000 SL                0.0                        0.12  \
# 2011 EH17                     3.0                        0.01
# 2011 SH189                    4.0                        0.11
# 2015 VL64                     5.0                        0.00
# 2018 SB3                      6.0                        0.01
#
#                 epoch_osculation  eccentricity  semi_major_axis (AU)
# name
# 503871 2000 SL         2460000.5          0.39                  1.54  \
# 2011 EH17              2460000.5          0.66                  0.73
# 2011 SH189             2460000.5          0.11                  1.22
# 2015 VL64              2460000.5          0.29                  0.91
# 2018 SB3               2460000.5          0.19                  1.14
#
#                 inclination (deg)  ascending_node_longitude (deg)
# name
# 503871 2000 SL              38.35                          207.73  \
# 2011 EH17                    3.00                          333.10
# 2011 SH189                   5.87                          182.72
# 2015 VL64                    0.71                           51.69
# 2018 SB3                     2.57                          339.57
#
#                 orbital_period (days)  perihelion_distance (AU)
# name
# 503871 2000 SL                 698.23                      0.93  \
# 2011 EH17                      228.21                      0.25
# 2011 SH189                     494.36                      1.09
# 2015 VL64                      316.60                      0.65
# 2018 SB3                       446.66                      0.93
#
#                 perihelion_argument  aphelion_distance (AU)  perihelion_time
# name
# 503871 2000 SL                70.20                    2.15       2460116.16  \
# 2011 EH17                     35.95                    1.21       2459900.03
# 2011 SH189                   217.46                    1.35       2459822.53
# 2015 VL64                    225.15                    1.17       2460096.88
# 2018 SB3                     313.74                    1.36       2460113.19
#
#                 mean_anomaly (deg)  mean_motion (revs/year)
# name
# 503871 2000 SL              300.37                     0.52
# 2011 EH17                   158.49                     1.58
# 2011 SH189                  129.60                     0.73
# 2015 VL64                   250.41                     1.14
# 2018 SB3                    269.17                     0.81

# %% [markdown]
# Data set clean!
